# %% [markdown]
# <a href="https://colab.research.google.com/github/AabhinavAnand/Netflix-Data-Visualization-/blob/main/heat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/heart.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
# eda EXplotary data analysis
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['HeartDisease'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
def plotting(var, num):
  plt.subplot(2,2,num)
  sns.histplot(df[var], kde=True)

plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)

plt.tight_layout()

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 220     10
# 223     10
# 204      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %%
ch_mean = df.loc[df['Cholesterol']!=0, 'Cholesterol'].mean()
ch_mean
# Out:
# np.float64(244.6353887399464)

# %%
df['Cholesterol']=df['Cholesterol'].replace(0,ch_mean)
df['Cholesterol']=df['Cholesterol'].round(2)

# %%
resting_bp_mean = df.loc[df['RestingBP'] != 0, 'RestingBP'].mean()

df['RestingBP'] = df['RestingBP'].replace(0, resting_bp_mean)

df['RestingBP'] = df['RestingBP'].round(2)

# %%
def plotting(var, num):
  plt.subplot(2,2,num)
  sns.histplot(df[var], kde=True)

plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)

plt.tight_layout()

# %%
pip install sheryanalysis==0.1.0

# %%
import sheryanalysis as sh
sh.analyze(df)
# Out:
# 🔍 Basic Analysis Report
# INFO:sheryanalysis:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# INFO:sheryanalysis:------------------------------------------------------------
# 📏 Shape: (918, 12)
# INFO:sheryanalysis:📏 Shape: (918, 12)
# 🧱 Columns: ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']
# INFO:sheryanalysis:🧱 Columns: ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']
# ✅ No null values found
# INFO:sheryanalysis:
# ✅ No null values found
# 🔠 Categorical Columns: ['Sex', 'ChestPainType', 'Cholesterol', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'HeartDisease']
# INFO:sheryanalysis:
# ...

# %%
sns.countplot(x = df['Sex'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x=df['ChestPainType'], hue=df['HeartDisease'])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x=df['FastingBS'], hue=df['HeartDisease'])
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
sns.boxplot(x='HeartDisease', y='Cholesterol', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x='HeartDisease', y='Age', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
#Data pewprocessing and cleaning
df_encode = pd.get_dummies(df,drop_first=True)

# %%
df_encode
# Out:
#      Age  RestingBP  FastingBS  MaxHR  Oldpeak  HeartDisease  Sex_M  \
# 0     40      140.0          0    172      0.0             0   True
# 1     49      160.0          0    156      1.0             1  False
# 2     37      130.0          0     98      0.0             0   True
# 3     48      138.0          0    108      1.5             1  False
# 4     54      150.0          0    122      0.0             0   True
# ..   ...        ...        ...    ...      ...           ...    ...
# 913   45      110.0          0    132      1.2             1   True
# 914   68      144.0          1    141      3.4             1   True
# 915   57      130.0          0    115      1.2             1   True
# 916   57      130.0          0    174      0.0             1  False
# 917   38      138.0          0    173      0.0             0   True
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  Cholesterol_ATA  \
# ...

# %%
df_encode = df_encode.astype(int)

# %%
df_encode
# Out:
#      Age  RestingBP  FastingBS  MaxHR  Oldpeak  HeartDisease  Sex_M  \
# 0     40        140          0    172        0             0      1
# 1     49        160          0    156        1             1      0
# 2     37        130          0     98        0             0      1
# 3     48        138          0    108        1             1      0
# 4     54        150          0    122        0             0      1
# ..   ...        ...        ...    ...      ...           ...    ...
# 913   45        110          0    132        1             1      1
# 914   68        144          1    141        3             1      1
# 915   57        130          0    115        1             1      1
# 916   57        130          0    174        0             1      0
# 917   38        138          0    173        0             0      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  Cholesterol_ATA  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

numerical_cols = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

# keep only columns that exist
numerical_cols = [col for col in numerical_cols if col in df_encode.columns]

scaler = StandardScaler()
df_encode[numerical_cols] = scaler.fit_transform(df_encode[numerical_cols])

df_encode.head()
# Out:
#         Age  RestingBP  FastingBS     MaxHR   Oldpeak  HeartDisease  Sex_M  \
# 0 -1.433140   0.414885          0  1.382928 -0.727592             0      1
# 1 -0.478484   1.527224          0  0.754157  0.282891             1      0
# 2 -1.751359  -0.141284          0 -1.525138 -0.727592             0      1
# 3 -0.584556   0.303651          0 -1.132156  0.282891             1      0
# 4  0.051881   0.971054          0 -0.581981 -0.727592             0      1
#
#    ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  Cholesterol_ATA  \
# 0                  1                  0                 0                1
# 1                  0                  1                 0                0
# 2                  1                  0                 0                1
# 3                  0                  0                 0                0
# 4                  0                  1                 0                0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_303/1616610133.py in <cell line: 0>()
#       1 numerical_cols = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
#       2 scaler = StandardScaler()
# ----> 3 df_encode[numerical_cols] = scaler.fit_transform(df_encode[numerical_cols])
#       4 df_encode.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# ...
